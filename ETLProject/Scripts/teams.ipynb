# %% [markdown]
# # Data extraction

# %% [markdown]
# ## FIFA teams web scraping

# %% [markdown]
# Web scraping of <a href='www.fifaindex.com/es/teams'>FIFAindex</a> in order to find information on each team:
# * Team name
# * League
# * Rival team
# * Attack
# * Midfield
# * Defence
# * Transfer Budget

# %% [markdown]
# ### First step
# The site www.FIFAindex.com/es/teams was scraped to find the links to each team description. In order to to so, Chrome WebDriver was used to iterate through the several pages containing the links to each team details.

# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
import pandas as pd

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.fifaindex.com/teams/'
browser.visit(url)

# %%
links = []
for page in range(25):
    html = browser.html
    soup = bs(html, 'html.parser')
    
    teams = soup.find_all('a', class_="link-team")
    
    for team in teams:
        link = team['href']
        if link not in links:
            links.append(link)
    
    print(f"Page {page} complete")

    # Click the 'Next' button on each page
    try:
        browser.click_link_by_partial_text('Next Page')
          
    except:
        print("Scraping Complete")
        break
        

teams_url_list = ['http://www.fifaindex.com' + link for link in links]
# Out:
# Page 0 complete
# Page 1 complete
# Page 2 complete
# Page 3 complete
# Page 4 complete
# Page 5 complete
# Page 6 complete
# Page 7 complete
# Page 8 complete
# Page 9 complete
# Page 10 complete
# Page 11 complete
# Page 12 complete
# Page 13 complete
# Page 14 complete
# Page 15 complete
# Page 16 complete
# Page 17 complete
# Page 18 complete
# Page 19 complete
# Page 20 complete
# Page 21 complete
# Scraping Complete

# %%
print(f"Total number of links obtained: {len(links)}\n")
print("The first 5 links are:")
for x in range(5):
    print(teams_url_list[x])
# Out:
# Total number of links obtained: 652
#
# The first 5 links are:
# http://www.fifaindex.com/es/team/241/fc-barcelona/
# http://www.fifaindex.com/es/team/243/real-madrid/
# http://www.fifaindex.com/es/team/45/juventus/
# http://www.fifaindex.com/es/team/10/manchester-city/
# http://www.fifaindex.com/es/team/21/fc-bayern/

# %% [markdown]
# ### Second step
# Each collected url was scraped in order to obtained the details of the teams

# %% [markdown]
# *Trial with one team to observe the HTML structure*

# %%
url = 'https://www.fifaindex.com/es/team/241/fc-barcelona/'
response = requests.get(url)
soup = bs(response.text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/favicon.ico" rel="icon"/>
#   <link href="/ar/team/241/fc-barcelona/" hreflang="ar" rel="alternate"/>
#   <link href="/cs/team/241/fc-barcelona/" hreflang="cs" rel="alternate"/>
#   <link href="/da/team/241/fc-barcelona/" hreflang="da" rel="alternate"/>
#   <link href="/de/team/241/fc-barcelona/" hreflang="de" rel="alternate"/>
#   <link href="/team/241/fc-barcelona/" hreflang="en" rel="alternate"/>
#   <link href="/es/team/241/fc-barcelona/" hreflang="es" rel="alternate"/>
#   <link href="/es-mx/team/241/fc-barcelona/" hreflang="es-mx" rel="alternate"/>
#   <link href="/fr/team/241/fc-barcelone/" hreflang="fr" rel="alternate"/>
#   <link href="/it/team/241/fc-barcellona/" hreflang="it" rel="alternate"/>
#   <link href="/ja/team/241/fc%EF%BE%8A%EF%BE%9E%EF%BE%99%EF%BD%BE%EF%BE%9B%EF%BE%85/" hreflang="ja" rel="alternate"/>
#   <link href="/hu/team/241/fc-barcelona/" hreflang="hu" rel="alternate"/>
#   <link href="/nl/team/241/fc-barcelona/" hreflang="nl" rel="alternate"/>
#   <link href="/no/team/241/fc-barcelona/" hreflang="no" rel="alternate"/>
#   <link href="/pl/team/241/fc-barcelona/" hreflang="pl" rel="alternate"/>
#   <link href="/pt/team/241/fc-barcelona/" hreflang="pt" rel="alternate"/>
#   <link href="/pt-br/team/241/fc-barcelona/" hreflang="pt-br" rel="alternate"/>
#   <link href="/ru/team/241/fc-barcelona/" hreflang="ru" rel="alternate"/>
#   <link href="/sv/team/241/fc-barcelona/" hreflang="sv" rel="alternate"/>
#   <link href="/tr/team/241/fc-barcelona/" hreflang="tr" rel="alternate"/>
#   <link href="/zh-hant/team/241/%E5%B7%B4%E5%A1%9E%E9%9A%86%E6%8B%BF/" hreflang="zh-hant" rel="alternate"/>
#   <link href="https://www.fifaindex.com/es/team/241/fc-barcelona/" rel="canonical"/>
#   <meta content="https://www.fifaindex.com/es/team/241/fc-barcelona/" property="og:url"/>
#   <meta content="FC Barcelona - FIFA 19 - Estad. Equipo" property="og:title"/>
#   <meta content="https://www.fifaindex.com/static/FIFA19/images/crest/5/light/241.png" property="og:image"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="FC Barcelona is a team from Spain. The main rival of FC Barcelona is Real Madrid. View their complete FIFA 19 stats and more at FIFA Index." name="twitter:description"/>
#   <title>
#    FC Barcelona - FIFA 19 - Estad. Equipo - FIFA Index
#   </title>
#   <link href="/static/CACHE/css/619b75a3cd1b.css" rel="stylesheet" type="text/css"/>
#   <link href="/static/app/images/icons/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="/static/app/images/icons/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="/static/app/images/icons/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="/static/app/images/icons/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="/static/app/images/icons/apple-touch-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#   <link href="/static/app/images/icons/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="/static/app/images/icons/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="/static/app/images/icons/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="/static/app/images/icons/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
#   <link href="/static/app/images/icons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/static/app/images/icons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/static/app/images/icons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/static/app/images/icons/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PWRSC6S');
#   </script>
#  </head>
#  <body class="page page-teamview fifa-19">
#   <header>
#    <nav class="navbar navbar-expand-lg navbar-light fixed-top bg-gradient-light px-md-5">
#     <button aria-controls="filterCollapse" aria-expanded="false" aria-label="Toggle filters" class="navbar-toggler" data-target="#filters" data-toggle="collapse" type="button">
#      <span class="navbar-toggler-icon navbar-fa-icon">
#       <i class="fa fa-search">
#       </i>
#      </span>
#     </button>
#     <a class="navbar-brand" href="/es/">
#      FIFA Index
#     </a>
#     <button aria-controls="navbarCollapse" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarCollapse" data-toggle="collapse" type="button">
#      <span class="navbar-toggler-icon">
#      </span>
#     </button>
#     <div class="collapse navbar-collapse" id="navbarCollapse">
#      <ul class="navbar-nav mr-auto">
#       <li class="nav-item ">
#        <a class="nav-link" href="/news/">
#         Noticias
#        </a>
#       </li>
#       <li class="nav-item active">
#        <a class="nav-link" href="/es/teams/">
#         Equipos
#        </a>
#       </li>
#       <li class="nav-item ">
#        <a class="nav-link" href="/es/players/top/">
#         Jugadores
#        </a>
#       </li>
#       <li class="nav-item ">
#        <a class="nav-link" href="/es/squads/">
#         Plantillas
#        </a>
#       </li>
#       <li class="nav-item ">
#        <a class="nav-link" href="/es/top-10/players/">
#         Comunidad
#        </a>
#       </li>
#       <li class="nav-item ">
#        <a class="nav-link" href="/contact/">
#         Contact
#        </a>
#       </li>
#      </ul>
#      <form class="form-inline fifa-search">
#       <input class="form-control" placeholder="Search" type="text"/>
#      </form>
#      <ul class="navbar-nav logged-in d-none">
#       <li class="nav-item dropdown">
#        <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle cursor-pointer" data-toggle="dropdown">
#         <span class="username">
#         </span>
#        </a>
#        <div class="dropdown-menu">
#         <a class="dropdown-item my-squads" href="">
#          Mis plantillas
#         </a>
#         <a class="dropdown-item" href="/accounts/email/">
#          Direcciones de correo electrónico
#         </a>
#         <a class="dropdown-item" href="/accounts/social/connections/">
#          Conexiones de Cuenta
#         </a>
#         <a class="dropdown-item" href="/accounts/password/change/">
#          Cambiar Contraseña
#         </a>
#         <a class="dropdown-item" href="/accounts/logout/">
#          Cerrar sesión
#         </a>
#        </div>
#       </li>
#      </ul>
#      <ul class="navbar-nav not-logged-in d-none">
#       <li class="nav-item">
#        <a class="nav-link" href="/accounts/login/">
#         Iniciar sesión
#        </a>
#       </li>
#      </ul>
#      <ul class="navbar-nav">
#       <li class="nav-item dropdown">
#        <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle cursor-pointer d-none d-lg-block" data-toggle="dropdown">
#         <i aria-hidden="true" class="fa fa-cog">
#         </i>
#        </a>
#        <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle cursor-pointer d-block d-lg-none" data-toggle="dropdown">
#         Ajustes
#        </a>
#        <div class="dropdown-menu">
#         <div class="px-4 py-3">
#          <div class="form-group">
#           <p>
#            Divisa
#           </p>
#           <div class="btn-group d-flex" role="group">
#            <button class="btn btn-outline-primary w-100 active" data-action="currency" data-currency="euro" type="button">
#             € Euros
#            </button>
#            <button class="btn btn-outline-primary w-100" data-action="currency" data-currency="dollar" type="button">
#             $ Dólares
#            </button>
#            <button class="btn btn-outline-primary w-100" data-action="currency" data-currency="pound" type="button">
#             £ Libras
#            </button>
#           </div>
#          </div>
#          <div class="form-group">
#           <p>
#            Units
#           </p>
#           <div class="btn-group d-flex" role="group">
#            <button class="btn btn-outline-primary w-100 active" data-action="units" data-units="metric" type="button">
#             Metric
#            </button>
#            <button class="btn btn-outline-primary w-100" data-action="units" data-units="imperial" type="button">
#             Imperial
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#      </ul>
#      <ul class="navbar-nav">
#       <li class="nav-item dropdown">
#        <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle cursor-pointer" data-toggle="dropdown">
#         Español
#        </a>
#        <div class="dropdown-menu">
#         <a class="dropdown-item" href="/setlang/?language=ar&amp;next=/ar/team/241/fc-barcelona/" rel="nofollow">
#          العربيّة
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=cs&amp;next=/cs/team/241/fc-barcelona/" rel="nofollow">
#          Česky
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=da&amp;next=/da/team/241/fc-barcelona/" rel="nofollow">
#          Dansk
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=de&amp;next=/de/team/241/fc-barcelona/" rel="nofollow">
#          Deutsch
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=en&amp;next=/team/241/fc-barcelona/" rel="nofollow">
#          English
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=es&amp;next=/es/team/241/fc-barcelona/" rel="nofollow">
#          Español
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=es-mx&amp;next=/es-mx/team/241/fc-barcelona/" rel="nofollow">
#          Español De México
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=fr&amp;next=/fr/team/241/fc-barcelone/" rel="nofollow">
#          Français
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=it&amp;next=/it/team/241/fc-barcellona/" rel="nofollow">
#          Italiano
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=ja&amp;next=/ja/team/241/fc%EF%BE%8A%EF%BE%9E%EF%BE%99%EF%BD%BE%EF%BE%9B%EF%BE%85/" rel="nofollow">
#          日本語
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=hu&amp;next=/hu/team/241/fc-barcelona/" rel="nofollow">
#          Magyar
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=nl&amp;next=/nl/team/241/fc-barcelona/" rel="nofollow">
#          Nederlands
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=no&amp;next=/no/team/241/fc-barcelona/" rel="nofollow">
#          Norsk
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=pl&amp;next=/pl/team/241/fc-barcelona/" rel="nofollow">
#          Polski
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=pt&amp;next=/pt/team/241/fc-barcelona/" rel="nofollow">
#          Português
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=pt-br&amp;next=/pt-br/team/241/fc-barcelona/" rel="nofollow">
#          Português Do Brasil
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=ru&amp;next=/ru/team/241/fc-barcelona/" rel="nofollow">
#          Русский
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=sv&amp;next=/sv/team/241/fc-barcelona/" rel="nofollow">
#          Svenska
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=tr&amp;next=/tr/team/241/fc-barcelona/" rel="nofollow">
#          Türkçe
#         </a>
#         <a class="dropdown-item" href="/setlang/?language=zh-hant&amp;next=/zh-hant/team/241/%E5%B7%B4%E5%A1%9E%E9%9A%86%E6%8B%BF/" rel="nofollow">
#          繁體中文
#         </a>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </nav>
#   </header>
#   <main role="main">
#    <div class="container pt-5">
#     <script type="application/javascript">
#      var messages = [];
#     </script>
#     <div class="row d-none">
#      <div class="col-md-8 offset-md-2 messages mb-3">
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-lg-4 filters" id="filters">
#       <form action="/es/teams/" class="mb-3" method="get">
#        <div class="form-group align-items-center row">
#         <label class="col-md-5 col-form-label" for="id_name">
#          Nombre
#         </label>
#         <div class="col-md-7 d-flex">
#          <input class="form-control" id="id_name" name="name" placeholder="Nombre" title="" type="text"/>
#         </div>
#        </div>
#        <div class="form-group align-items-center row">
#         <label class="col-md-5 col-form-label" for="id_league">
#          Liga
#         </label>
#         <div class="col-md-7 d-flex">
#          <select class="form-control" id="id_league" multiple="multiple" name="league" title="">
#           <option value="2076">
#            3. Liga
#           </option>
#           <option value="2012">
#            CSL
#           </option>
#           <option value="382">
#            Agentes Libres
#           </option>
#           <option value="353">
#            SAF
#           </option>
#           <option value="351">
#            Hyundai A-League
#           </option>
#           <option value="350">
#            Saudi Professional League
#           </option>
#           <option value="349">
#            Meiji Yasuda J1
#           </option>
#           <option value="341">
#            LIGA Bancomer MX
#           </option>
#           <option value="336">
#            Liga Dimayor
#           </option>
#           <option value="335">
#            Camp. Scotiabank
#           </option>
#           <option value="308">
#            Liga NOS
#           </option>
#           <option value="189">
#            RSL
#           </option>
#           <option value="83">
#            K-League 1
#           </option>
#           <option value="80">
#            Ö. Bundesliga
#           </option>
#           <option value="76">
#            Resto del mundo
#           </option>
#           <option value="68">
#            Süper Lig
#           </option>
#           <option value="66">
#            Ekstraklasa
#           </option>
#           <option value="65">
#            SSE Airtricity Lge
#           </option>
#           <option value="61">
#            EFL League Two
#           </option>
#           <option value="60">
#            EFL League One
#           </option>
#           <option value="56">
#            Allsvenskan
#           </option>
#           <option value="54">
#            LaLiga 1 I 2 I 3
#           </option>
#           <option value="53">
#            LaLiga Santander
#           </option>
#           <option value="50">
#            Scottish Prem
#           </option>
#           <option value="41">
#            Eliteserien
#           </option>
#           <option value="39">
#            MLS
#           </option>
#           <option value="32">
#            Calcio B
#           </option>
#           <option value="31">
#            Serie A TIM
#           </option>
#           <option value="20">
#            Bundesliga 2
#           </option>
#           <option value="19">
#            Bundesliga
#           </option>
#           <option value="17">
#            Domino's Ligue 2
#           </option>
#           <option value="16">
#            Ligue 1 Conforama
#           </option>
#           <option value="14">
#            EFL Championship
#           </option>
#           <option value="13">
#            Premier League
#           </option>
#           <option value="10">
#            Eredivisie
#           </option>
#           <option value="7">
#            Liga do Brasil
#           </option>
#           <option value="4">
#            Pro League
#           </option>
#           <option value="1">
#            Superliga
#           </option>
#          </select>
#         </div>
#        </div>
#        <div class="form-group align-items-center row">
#         <label class="col-md-5 col-form-label" for="id_attackrating_0">
#          Ataque
#         </label>
#         <div class="col-md-7 d-flex">
#          <input class="form-control" id="id_attackrating_0" name="attackrating_0" placeholder="Ataque" title="" type="number"/>
#          <input class="form-control" id="id_attackrating_1" name="attackrating_1" placeholder="Ataque" title="" type="number"/>
#         </div>
#        </div>
#        <div class="form-group align-items-center row">
#         <label class="col-md-5 col-form-label" for="id_midfieldrating_0">
#          Mediocampo
#         </label>
#         <div class="col-md-7 d-flex">
#          <input class="form-control" id="id_midfieldrating_0" name="midfieldrating_0" placeholder="Mediocampo" title="" type="number"/>
#          <input class="form-control" id="id_midfieldrating_1" name="midfieldrating_1" placeholder="Mediocampo" title="" type="number"/>
#         </div>
#        </div>
#        <div class="form-group align-items-center row">
#         <label class="col-md-5 col-form-label" for="id_defenserating_0">
#          Defensa
#         </label>
#         <div class="col-md-7 d-flex">
#          <input class="form-control" id="id_defenserating_0" name="defenserating_0" placeholder="Defensa" title="" type="number"/>
#          <input class="form-control" id="id_defenserating_1" name="defenserating_1" placeholder="Defensa" title="" type="number"/>
#         </div>
#        </div>
#        <div class="form-group align-items-center row">
#         <label class="col-md-5 col-form-label" for="id_overallrating_0">
#          Valoración general
#         </label>
#         <div class="col-md-7 d-flex">
#          <input class="form-control" id="id_overallrating_0" name="overallrating_0" placeholder="Valoración general" title="" type="number"/>
#          <input class="form-control" id="id_overallrating_1" name="overallrating_1" placeholder="Valoración general" title="" type="number"/>
#         </div>
#        </div>
#        <div class="form-group align-items-center row">
#         <label class="col-md-5 col-form-label" for="id_stars">
#          Valoración equipo
#         </label>
#         <div class="col-md-7 d-flex">
#          <select class="form-control" id="id_stars" name="stars" title="">
#           <option value="-1">
#           </option>
#           <option value="5">
#            ★★★★★
#           </option>
#           <option value="4.5">
#            ★★★★½
#           </option>
#           <option value="4">
#            ★★★★
#           </option>
#           <option value="3.5">
#            ★★★½
#           </option>
#           <option value="3">
#            ★★★
#           </option>
#           <option value="2.5">
#            ★★½
#           </option>
#           <option value="2">
#            ★★
#           </option>
#           <option value="1.5">
#            ★½
#           </option>
#           <option value="1">
#            ★
#           </option>
#           <option value="0.5">
#            ½
#           </option>
#          </select>
#         </div>
#        </div>
#        <div class="form-group align-items-center row">
#         <label class="col-md-5 col-form-label" for="id_transferbudget_0">
#          Presupuesto De Traspasos
#         </label>
#         <div class="col-md-7 d-flex">
#          <input class="form-control" id="id_transferbudget_0" name="transferbudget_0" placeholder="Presupuesto De Traspasos" title="" type="number"/>
#          <input class="form-control" id="id_transferbudget_1" name="transferbudget_1" placeholder="Presupuesto De Traspasos" title="" type="number"/>
#         </div>
#        </div>
#        <div class="form-group align-items-center row">
#         <label class="col-md-5 col-form-label" for="id_order">
#          <select class="form-control order_by" data-placeholder="Ordenar por" id="id_order_by" name="order_by">
#           <option value="-1">
#            Ordenar por
#           </option>
#           <option value="overallrating">
#            Valoración general
#           </option>
#           <option value="attackrating">
#            Ataque
#           </option>
#           <option value="midfieldrating">
#            Mediocampo
#           </option>
#           <option value="defenserating">
#            Defensa
#           </option>
#           <option value="transferbudget">
#            Presupuesto De Traspasos
#           </option>
#          </select>
#         </label>
#         <div class="col-md-7 d-flex">
#          <select class="form-control" id="id_order" name="order" title="">
#           <option value="desc">
#            Descending
#           </option>
#           <option value="asc">
#            Ascending
#           </option>
#          </select>
#         </div>
#        </div>
#        <input id="id_type" name="type" type="hidden"/>
#        <input id="id_currency" name="currency" type="hidden"/>
#        <div class="form-group text-right row sticky-bottom">
#         <div class="btn-group d-flex col-12" role="group">
#          <button class="btn btn-primary w-100" data-event-action="search" data-event-category="action" data-event-label="teams" type="submit">
#           <i class="fas fa-search">
#           </i>
#           Buscar
#          </button>
#         </div>
#        </div>
#       </form>
#      </div>
#      <div class="col-lg-8">
#       <nav>
#        <ol class="breadcrumb bg-primary">
#         <li class="breadcrumb-item">
#          <a href="/es/">
#           Home
#          </a>
#         </li>
#         <li class="breadcrumb-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#           FIFA 19
#           <span class="caret">
#           </span>
#          </a>
#          <div class="dropdown-menu">
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/">
#            FIFA 19
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa18wc_271/">
#            FIFA 18 WC
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa18_278/">
#            FIFA 18
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa17_173/">
#            FIFA 17
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa16_73/">
#            FIFA 16
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa15_14/">
#            FIFA 15
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa14_13/">
#            FIFA 14
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa13_10/">
#            FIFA 13
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa12_9/">
#            FIFA 12
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa11_7/">
#            FIFA 11
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa10_6/">
#            FIFA 10
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa09_5/">
#            FIFA 09
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa08_4/">
#            FIFA 08
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa07_3/">
#            FIFA 07
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa06_2/">
#            FIFA 06
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa05_1/">
#            FIFA 05
#           </a>
#          </div>
#         </li>
#         <li class="breadcrumb-item dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-placement="bottom" data-toggle="dropdown" href="#" role="button">
#           9 de Mayo de 2019
#           <span class="caret">
#           </span>
#          </a>
#          <div class="dropdown-menu fade-out">
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/">
#            9 de Mayo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_337/">
#            7 de Mayo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_336/">
#            2 de Mayo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_335/">
#            29 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_334/">
#            25 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_333/">
#            23 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_332/">
#            18 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_331/">
#            16 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_330/">
#            15 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_329/">
#            11 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_328/">
#            8 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_327/">
#            4 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_326/">
#            1 de Abril de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_325/">
#            28 de Marzo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_324/">
#            25 de Marzo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_323/">
#            21 de Marzo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_322/">
#            20 de Marzo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_321/">
#            18 de Marzo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_320/">
#            14 de Marzo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_319/">
#            4 de Marzo de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_318/">
#            28 de Febrero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_317/">
#            22 de Febrero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_316/">
#            21 de Febrero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_315/">
#            14 de Febrero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_314/">
#            11 de Febrero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_313/">
#            7 de Febrero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_312/">
#            4 de Febrero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_311/">
#            31 de Enero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_310/">
#            28 de Enero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_309/">
#            24 de Enero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_308/">
#            21 de Enero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_307/">
#            17 de Enero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_306/">
#            14 de Enero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_305/">
#            10 de Enero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_304/">
#            7 de Enero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_303/">
#            3 de Enero de 2019
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_302/">
#            27 de Diciembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_301/">
#            20 de Diciembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_300/">
#            17 de Diciembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_299/">
#            13 de Diciembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_298/">
#            3 de Diciembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_297/">
#            26 de Noviembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_296/">
#            15 de Noviembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_295/">
#            12 de Noviembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_294/">
#            5 de Noviembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_293/">
#            31 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_292/">
#            29 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_291/">
#            25 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_290/">
#            23 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_289/">
#            22 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_288/">
#            18 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_287/">
#            15 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_286/">
#            11 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_285/">
#            9 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_284/">
#            4 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_283/">
#            1 de Octubre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_282/">
#            27 de Septiembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_281/">
#            24 de Septiembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_280/">
#            20 de Septiembre de 2018
#           </a>
#           <a class="dropdown-item" href="/es/team/241/fc-barcelona/fifa19_279/">
#            21 de Agosto de 2018
#           </a>
#          </div>
#         </li>
#         <li class="breadcrumb-item">
#          <a href="/es/teams/">
#           Equipos
#          </a>
#         </li>
#         <li class="breadcrumb-item active">
#          FC Barcelona
#         </li>
#        </ol>
#       </nav>
#       <div class="row pt-3">
#        <div class="col-sm-6 col-md-7">
#         <div class="d-flex mb-3 align-items-center">
#          <div class="align-self-center">
#           <img alt="FC Barcelona" class="team size-10" data-src="/static/FIFA19/images/crest/10/light/241.png" data-srcset="/static/FIFA19/images/crest/10/light/241@2x.png 2x, /static/FIFA19/images/crest/10/light/241@3x.png 3x" src="/static/FIFA19/images/crest/10/light/notfound.png" title="FC Barcelona"/>
#          </div>
#          <div class="pl-3">
#           <h1>
#            FC Barcelona
#           </h1>
#           <p>
#            <span class="star">
#             <i class="fas fa-star fa-lg">
#             </i>
#             <i class="fas fa-star fa-lg">
#             </i>
#             <i class="fas fa-star fa-lg">
#             </i>
#             <i class="fas fa-star fa-lg">
#             </i>
#             <i class="fas fa-star fa-lg">
#             </i>
#            </span>
#           </p>
#           <h2>
#            <a class="link-league" href="/es/teams/?league=53" title="LaLiga Santander">
#             LaLiga Santander
#            </a>
#           </h2>
#          </div>
#         </div>
#         <div class="mb-4">
#          <div class="btn-group d-flex" role="group">
#           <button class="btn btn-outline-primary w-100" data-objectid="241" data-placement="left" data-toggle="tooltip" data-type="team" data-vote="up" title="Contributes to the ranking of the the Top 10s, should be based on performances, not on personal bias." type="button">
#            <i class="fa fa-thumbs-up">
#            </i>
#            Like (
#            <span class="count">
#             11
#            </span>
#            )
#           </button>
#           <button class="btn btn-outline-danger w-100" data-objectid="241" data-placement="right" data-toggle="tooltip" data-type="team" data-vote="down" title="Contributes to the ranking of the the Top 10s, should be based on performances, not on personal bias." type="button">
#            <i class="fa fa-thumbs-down">
#            </i>
#            Dislike (
#            <span class="count">
#             0
#            </span>
#            )
#           </button>
#          </div>
#         </div>
#        </div>
#        <div class="col-sm-6 col-md-5">
#         <div class="card mb-5">
#          <h5 class="card-header">
#           <span>
#            Información De Equipo
#           </span>
#          </h5>
#          <ul class="list-group list-group-flush">
#           <li class="list-group-item">
#            Equipo Rival
#            <span class="float-right">
#             <a class="link-team" href="/es/team/243/real-madrid/" title="Real Madrid">
#              Real Madrid
#             </a>
#            </span>
#           </li>
#           <li class="list-group-item">
#            Ataque
#            <span class="float-right">
#             <span class="badge badge-dark rating r2">
#              87
#             </span>
#            </span>
#           </li>
#           <li class="list-group-item">
#            Mediocampo
#            <span class="float-right">
#             <span class="badge badge-dark rating r2">
#              86
#             </span>
#            </span>
#           </li>
#           <li class="list-group-item">
#            Defensa
#            <span class="float-right">
#             <span class="badge badge-dark rating r2">
#              85
#             </span>
#            </span>
#           </li>
#           <li class="list-group-item">
#            Presupuesto De Traspasos
#            <span class="data-currency data-currency-euro float-right">
#             €188.000.000
#            </span>
#            <span class="data-currency data-currency-dollar float-right">
#             $218.000.000
#            </span>
#            <span class="data-currency data-currency-pound float-right">
#             £165.500.000
#            </span>
#           </li>
#           <li class="list-group-item logged-in d-none">
#            <a class="btn btn-block btn-sm btn-primary" data-event-action="click" data-event-category="action" data-event-label="create_new_squad" href="/es/squads/create/?teamid=241">
#             Crear Nueva Plantilla
#            </a>
#           </li>
#           <li class="list-group-item">
#            <a class="btn btn-block btn-sm btn-primary" href="/es/transfer-rumours/team/241/fc-barcelona/">
#             <i class="fa fa-exchange-alt">
#             </i>
#             View transfer rumours
#            </a>
#           </li>
#          </ul>
#          <div class="text-center">
#           <a aria-label="" class="resp-sharing-button__link" data-event-action="share" data-event-category="action" data-event-label="facebook" href="https://facebook.com/sharer/sharer.php?u=https://www.fifaindex.com/es/team/241/fc-barcelona/" target="_blank">
#            <div class="resp-sharing-button resp-sharing-button--facebook resp-sharing-button--small">
#             <div aria-hidden="true" class="resp-sharing-button__icon resp-sharing-button__icon--solid">
#              <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#               <path d="M18.77 7.46H14.5v-1.9c0-.9.6-1.1 1-1.1h3V.5h-4.33C10.24.5 9.5 3.44 9.5 5.32v2.15h-3v4h3v12h5v-12h3.85l.42-4z">
#               </path>
#              </svg>
#             </div>
#            </div>
#           </a>
#           <a aria-label="" class="resp-sharing-button__link" data-event-action="share" data-event-category="action" data-event-label="twitter" href="https://twitter.com/intent/tweet/?text=FC%20Barcelona&amp;url=https://www.fifaindex.com/es/team/241/fc-barcelona/" target="_blank">
#            <div class="resp-sharing-button resp-sharing-button--twitter resp-sharing-button--small">
#             <div aria-hidden="true" class="resp-sharing-button__icon resp-sharing-button__icon--solid">
#              <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#               <path d="M23.44 4.83c-.8.37-1.5.38-2.22.02.93-.56.98-.96 1.32-2.02-.88.52-1.86.9-2.9 1.1-.82-.88-2-1.43-3.3-1.43-2.5 0-4.55 2.04-4.55 4.54 0 .36.03.7.1 1.04-3.77-.2-7.12-2-9.36-4.75-.4.67-.6 1.45-.6 2.3 0 1.56.8 2.95 2 3.77-.74-.03-1.44-.23-2.05-.57v.06c0 2.2 1.56 4.03 3.64 4.44-.67.2-1.37.2-2.06.08.58 1.8 2.26 3.12 4.25 3.16C5.78 18.1 3.37 18.74 1 18.46c2 1.3 4.4 2.04 6.97 2.04 8.35 0 12.92-6.92 12.92-12.93 0-.2 0-.4-.02-.6.9-.63 1.96-1.22 2.56-2.14z">
#               </path>
#              </svg>
#             </div>
#            </div>
#           </a>
#           <a aria-label="" class="resp-sharing-button__link" data-event-action="share" data-event-category="action" data-event-label="whatsapp" href="whatsapp://send?text=FC%20Barcelona%20https://www.fifaindex.com/es/team/241/fc-barcelona/" target="_blank">
#            <div class="resp-sharing-button resp-sharing-button--whatsapp resp-sharing-button--small">
#             <div aria-hidden="true" class="resp-sharing-button__icon resp-sharing-button__icon--solid">
#              <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#               <path d="M20.1 3.9C17.9 1.7 15 .5 12 .5 5.8.5.7 5.6.7 11.9c0 2 .5 3.9 1.5 5.6L.6 23.4l6-1.6c1.6.9 3.5 1.3 5.4 1.3 6.3 0 11.4-5.1 11.4-11.4-.1-2.8-1.2-5.7-3.3-7.8zM12 21.4c-1.7 0-3.3-.5-4.8-1.3l-.4-.2-3.5 1 1-3.4L4 17c-1-1.5-1.4-3.2-1.4-5.1 0-5.2 4.2-9.4 9.4-9.4 2.5 0 4.9 1 6.7 2.8 1.8 1.8 2.8 4.2 2.8 6.7-.1 5.2-4.3 9.4-9.5 9.4zm5.1-7.1c-.3-.1-1.7-.9-1.9-1-.3-.1-.5-.1-.7.1-.2.3-.8 1-.9 1.1-.2.2-.3.2-.6.1s-1.2-.5-2.3-1.4c-.9-.8-1.4-1.7-1.6-2-.2-.3 0-.5.1-.6s.3-.3.4-.5c.2-.1.3-.3.4-.5.1-.2 0-.4 0-.5C10 9 9.3 7.6 9 7c-.1-.4-.4-.3-.5-.3h-.6s-.4.1-.7.3c-.3.3-1 1-1 2.4s1 2.8 1.1 3c.1.2 2 3.1 4.9 4.3.7.3 1.2.5 1.6.6.7.2 1.3.2 1.8.1.6-.1 1.7-.7 1.9-1.3.2-.7.2-1.2.2-1.3-.1-.3-.3-.4-.6-.5z">
#               </path>
#              </svg>
#             </div>
#            </div>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-md-8">
#         <div class="card mb-5">
#          <h5 class="card-header">
#           Alineación
#          </h5>
#          <div class="card-body">
#           <div class="formation" style="height:600px;">
#            <div class="center-circle">
#            </div>
#            <div class="field left">
#             <div class="penalty-area">
#             </div>
#            </div>
#            <div class="field right">
#             <div class="penalty-area">
#             </div>
#            </div>
#            <div class="player" style="left:50.0%;bottom:3.5%;">
#             <a class="link-player" href="/es/player/192448/marc-andr%C3%A9-ter-stegen/" title="Marc-André ter Stegen">
#              <img alt="Marc-André ter Stegen" class="player size-5" data-src="/static/FIFA19/images/players/5/192448.png" data-srcset="/static/FIFA19/images/players/5/192448@2x.png 2x, /static/FIFA19/images/players/5/192448@3x.png 3x" src="/static/FIFA19/images/players/5/notfound.png" title="Marc-André ter Stegen"/>
#             </a>
#             <div class="name">
#              <a class="link-player" href="/es/player/192448/marc-andr%C3%A9-ter-stegen/" title="Marc-André ter Stegen">
#               Stegen
#              </a>
#             </div>
#            </div>
#            <div class="player" style="left:89%;bottom:21.5%;">
#             <a class="link-player" href="/es/player/199564/sergi-roberto/" title="Sergi Roberto">
#              <img alt="Sergi Roberto" class="player size-5" data-src="/static/FIFA19/images/players/5/199564.png" data-srcset="/static/FIFA19/images/players/5/199564@2x.png 2x, /static/FIFA19/images/players/5/199564@3x.png 3x" src="/static/FIFA19/images/players/5/notfound.png" title="Sergi Roberto"/>
#             </a>
#             <div class="name">
#              <a class="link-player" href="/es/player/199564/sergi-roberto/" title="Sergi Roberto">
#               Sergi Roberto
#              </a>
#             </div>
#            </div>
#            <div class="player" style="left:70.34%;bottom:16.080000000000002%;">
#             <a class="link-player" href="/es/player/152729/piqu%C3%A9/" title="Piqué">
#              <img alt="Piqué" class="player size-5" data-src="/static/FIFA19/images/players/5/152729.png" data-srcset="/static/FIFA19/images/players/5/152729@2x.png 2x, /static/FIFA19/images/players/5/152729@3x.png 3x" src="/static/FIFA19/images/players/5/notfound.png" title="Piqué"/>
#             </a>
#             <div class="name">
#              <a class="link-player" href="/es/player/152729/piqu%C3%A9/" title="Piqué">
#               Piqué
#              </a>
#             </div>
#            </div>
#            <div class="player" style="left:28.749999999999996%;bottom:16.5%;">
#             <a class="link-player" href="/es/player/220440/cl%C3%A9ment-lenglet/" title="Clément Lenglet">
#              <img alt="Clément Lenglet" class="player size-5" data-src="/static/FIFA19/images/players/5/220440.png" data-srcset="/static/FIFA19/images/players/5/220440@2x.png 2x, /static/FIFA19/images/players/5/220440@3x.png 3x" src="/static/FIFA19/images/players/5/notfound.png" title="
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-sm-6 col-md-6 col-lg-6">
#         <div class="card mb-5">
#          <h5 class="card-header">
#           Estilo defensivo
#          </h5>
#          <div class="card-body">
#           <p class="">
#            Estilo defensivo
#            <span class="float-right">
# ...
#            </a>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="link-player" href="/es/player/239231/cucurella/" title="Cucurella">
#             <img alt="Cucurella" class="player size-5" data-src="/static/FIFA19/images/players/5/239231.png" data-srcset="/static/FIFA19/images/players/5/239231@2x.png 2x, /static/FIFA19/images/players/5/239231@3x.png 3x" src="/static/FIFA19/images/players/5/notfound.png" title="Cucurella"/>
#            </a>
#           </td>
#           <td data-title="Nacionalidad">
#            <a class="link-nation" href="/es/players/?nationality=45" title="España">
#             <img alt="España" class="nation size-2" data-src="/static/FIFA19/images/flags/2/45.png" data-srcset="/static/FIFA19/images/flags/2/45@2x.png 2x, /static/FIFA19/images/flags/2/45@3x.png 3x" src="/static/app/images/1.png" title="España"/>
#            </a>
#           </td>
#           <td data-title="MED / POT">
#            <span class="badge badge-dark rating r3">
#             75
#            </span>
#            <span class="badge badge-dark rating r2">
#             84
#            </span>
#           </td>
#           <td data-title="Nombre">
#            <a class="link-player" href="/es/player/239231/cucurella/" title="Cucurella">
#             Cucurella
#            </a>
#           </td>
#           <td data-title="Posiciones preferidas">
#            <a class="link-position" href="/es/players/?position=16" title="MI">
#             <span class="badge badge-dark position lm">
#              MI
#             </span>
#            </a>
#            <a class="link-position" href="/es/players/?position=7" title="LI">
#             <span class="badge badge-dark position lb">
#              LI
#             </span>
#            </a>
#           </td>
#           <td data-title="Edad">
#            20
#           </td>
#           <td data-title="Equipo">
#            <a class="link-team" href="/es/team/467/sd-eibar/" title="SD Eibar">
#             <img alt="SD Eibar" class="team size-3" data-src="/static/FIFA19/images/crest/3/light/467.png" data-srcset="/static/FIFA19/images/crest/3/light/467@2x.png 2x, /static/FIFA19/images/crest/3/light/467@3x.png 3x" src="/static/FIFA19/images/crest/3/light/notfound.png" title="SD Eibar"/>
#            </a>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="link-player" href="/es/player/228321/sergi-palencia/" title="Sergi Palencia">
#             <img alt="Sergi Palencia" class="player size-5" data-src="/static/FIFA19/images/players/5/228321.png" data-srcset="/static/FIFA19/images/players/5/228321@2x.png 2x, /static/FIFA19/images/players/5/228321@3x.png 3x" src="/static/FIFA19/images/players/5/notfound.png" title="Sergi Palencia"/>
#            </a>
#           </td>
#           <td data-title="Nacionalidad">
#            <a class="link-nation" href="/es/players/?nationality=45" title="España">
#             <img alt="España" class="nation size-2" data-src="/static/FIFA19/images/flags/2/45.png" data-srcset="/static/FIFA19/images/flags/2/45@2x.png 2x, /static/FIFA19/images/flags/2/45@3x.png 3x" src="/static/app/images/1.png" title="España"/>
#            </a>
#           </td>
#           <td data-title="MED / POT">
#            <span class="badge badge-dark rating r3">
#             72
#            </span>
#            <span class="badge badge-dark rating r2">
#             80
#            </span>
#           </td>
#           <td data-title="Nombre">
#            <a class="link-player" href="/es/player/228321/sergi-palencia/" title="Sergi Palencia">
#             Sergi Palencia
#            </a>
#           </td>
#           <td data-title="Posiciones preferidas">
#            <a class="link-position" href="/es/players/?position=3" title="LD">
#             <span class="badge badge-dark position rb">
#              LD
#             </span>
#            </a>
#           </td>
#           <td data-title="Edad">
#            23
#           </td>
#           <td data-title="Equipo">
#            <a class="link-team" href="/es/team/59/giron-burdeos/" title="Giron. Burdeos">
#             <img alt="Giron. Burdeos" class="team size-3" data-src="/static/FIFA19/images/crest/3/light/59.png" data-srcset="/static/FIFA19/images/crest/3/light/59@2x.png 2x, /static/FIFA19/images/crest/3/light/59@3x.png 3x" src="/static/FIFA19/images/crest/3/light/notfound.png" title="Giron. Burdeos"/>
#            </a>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="link-player" href="/es/player/236393/marc-cardona/" title="Marc Cardona">
#             <img alt="Marc Cardona" class="player size-5" data-src="/static/FIFA19/images/players/5/236393.png" data-srcset="/static/FIFA19/images/players/5/236393@2x.png 2x, /static/FIFA19/images/players/5/236393@3x.png 3x" src="/static/FIFA19/images/players/5/notfound.png" title="Marc Cardona"/>
#            </a>
#           </td>
#           <td data-title="Nacionalidad">
#            <a class="link-nation" href="/es/players/?nationality=45" title="España">
#             <img alt="España" class="nation size-2" data-src="/static/FIFA19/images/flags/2/45.png" data-srcset="/static/FIFA19/images/flags/2/45@2x.png 2x, /static/FIFA19/images/flags/2/45@3x.png 3x" src="/static/app/images/1.png" title="España"/>
#            </a>
#           </td>
#           <td data-title="MED / POT">
#            <span class="badge badge-dark rating r3">
#             72
#            </span>
#            <span class="badge badge-dark rating r2">
#             80
#            </span>
#           </td>
#           <td data-title="Nombre">
#            <a class="link-player" href="/es/player/236393/marc-cardona/" title="Marc Cardona">
#             Marc Cardona
#            </a>
#           </td>
#           <td data-title="Posiciones preferidas">
#            <a class="link-position" href="/es/players/?position=25" title="DC">
#             <span class="badge badge-dark position st">
#              DC
#             </span>
#            </a>
#            <a class="link-position" href="/es/players/?position=16" title="MI">
#             <span class="badge badge-dark position lm">
#              MI
#             </span>
#            </a>
#           </td>
#           <td data-title="Edad">
#            23
#           </td>
#           <td data-title="Equipo">
#            <a class="link-team" href="/es/team/467/sd-eibar/" title="SD Eibar">
#             <img alt="SD Eibar" class="team size-3" data-src="/static/FIFA19/images/crest/3/light/467.png" data-srcset="/static/FIFA19/images/crest/3/light/467@2x.png 2x, /static/FIFA19/images/crest/3/light/467@3x.png 3x" src="/static/FIFA19/images/crest/3/light/notfound.png" title="SD Eibar"/>
#            </a>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <a class="link-player" href="/es/player/193429/douglas/" title="Douglas">
#             <img alt="Douglas" class="player size-5" data-src="/static/FIFA19/images/players/5/193429.png" data-srcset="/static/FIFA19/images/players/5/193429@2x.png 2x, /static/FIFA19/images/players/5/193429@3x.png 3x" src="/static/FIFA19/images/players/5/notfound.png" title="Douglas"/>
#            </a>
#           </td>
#           <td data-title="Nacionalidad">
#            <a class="link-nation" href="/es/players/?nationality=54" title="Brasil">
#             <img alt="Brasil" class="nation size-2" data-src="/static/FIFA19/images/flags/2/54.png" data-srcset="/static/FIFA19/images/flags/2/54@2x.png 2x, /static/FIFA19/images/flags/2/54@3x.png 3x" src="/static/app/images/1.png" title="Brasil"/>
#            </a>
#           </td>
#           <td data-title="MED / POT">
#            <span class="badge badge-dark rating r3">
#             72
#            </span>
#            <span class="badge badge-dark rating r3">
#             72
#            </span>
#           </td>
#           <td data-title="Nombre">
#             <img alt="Uruguay" class="nation size-2" data-src="/static/FIFA19/images/flags/2/60.png" data-srcset="/static/FIFA19/images/flags/2/60@2x.png 2x, /static/FIFA19/images/flags/2/60@3x.png 3x" src="/static/app/images/1.png" title="Uruguay"/>
#            </a>
#           </td>
#           <td data-title="MED / POT">
#            <span class="badge badge-dark rating r4">
#             63
#            </span>
#            <span class="badge badge-dark rating r3">
#             78
#            </span>
#           </td>
#           <td data-title="Nombre">
#            <a class="link-player" href="/es/player/237658/santiago-bueno/" title="Santiago Bueno">
#             Santiago Bueno
#            </a>
#           </td>
#           <td data-title="Posiciones preferidas">
#            <a class="link-position" href="/es/players/?position=5" title="DFC">
#             <span class="badge badge-dark position cb">
#              DFC
#             </span>
#            </a>
#            <a class="link-position" href="/es/players/?position=7" title="LI">
#             <span class="badge badge-dark position lb">
#              LI
#             </span>
#            </a>
#           </td>
#           <td data-title="Edad">
#            20
#           </td>
#           <td data-title="Equipo">
#            <a class="link-team" href="/es/team/110062/girona-fc/" title="Girona FC">
#             <img alt="Girona FC" class="team size-3" data-src="/static/FIFA19/images/crest/3/light/110062.png" data-srcset="/static/FIFA19/images/crest/3/light/110062@2x.png 2x, /static/FIFA19/images/crest/3/light/110062@3x.png 3x" src="/static/FIFA19/images/crest/3/light/notfound.png" title="Girona FC"/>
#            </a>
#           </td>
#          </tr>
#         </tbody>
#        </table>
#       </div>
#       <div data-lozad="load_disqus" id="disqus_thread">
#       </div>
#       <script>
#        var disqus_config = function () {
#     this.language = 'es';
#     this.page.url = 'https://www.fifaindex.com/team/241/';
#     this.page.identifier = 'team_241';
#     this.page.title = 'FC Barcelona - Team - FIFA Index';
#     this.callbacks.onNewComment = [function () {
#         event('comment', 'posted', 'team_241');
#     }];
# };
# function load_disqus() {
#     (function () {
#         var d = document, s = d.createElement('script');
#         s.src = 'https://fifaindex.disqus.com/embed.js';
#         s.setAttribute('data-timestamp', +new Date());
#         (d.head || d.body).appendChild(s);
#     })();
# }
#       </script>
#       <noscript>
#        Please enable JavaScript to view the
#        <a href="https://disqus.com/?ref_noscript">
#         comments powered by Disqus.
#        </a>
#       </noscript>
#      </div>
#     </div>
#    </div>
#   </main>
#   <footer class="container-fluid p-5">
#    <p class="text-center text-muted">
#     © www.fifaindex.com 2019 -
#     <a href="/tos.pdf" target="_blank">
#      Términos De Servicio
#     </a>
#     -
#     <a href="/cookies/">
#      Cookie Policy
#     </a>
#    </p>
#   </footer>
#   <script crossorigin="anonymous" src="https://browser.sentry-cdn.com/4.5.3/bundle.min.js">
#   </script>
#   <script>
#    Sentry.init({ dsn: 'https://19c8565ffc3848d2a1386d5dd731758d@sentry.io/1385887' });
#   </script>
#   <script src="/static/CACHE/js/2e4238f2a56b.js" type="text/javascript">
#   </script>
#   <script>
#    bidi = false;
#         min = "mín.";
#         max = "máx.";
#         select_option = "Selecciona Opción";
#         add_player = "Añadir Jug.";
#         remove_squad_confirmation = "¿Seguro que quieres borrar este Sistema de juego?";
#         root = '/es/';
#         if (typeof uid != 'undefined'){
#             $('.logged-in').removeClass('d-none');
#             $('.uid-'+uid).removeClass('d-none');
#             $('.username').html(username);
#             $('a.my-squads').attr('href', mysquads);
#         } else {
#             $('.not-logged-in').removeClass('d-none');
#         }
#
#         if (typeof messages != 'undefined') {
#             messages.forEach(function (message){
#                 html = '<div class="alert alert-'+message.type+' alert-dismissable"><button type="button" class="close" data-dismiss="alert" aria-hidden="true">×</button>'+message.message+'</div>';
#                 $('main .messages').append(html).parent().removeClass('d-none');
#             });
#         }
#   </script>
#   <script>
#    event('page', 'view', 'team_detail');
#   </script>
#  </body>
# </html>

# %% [markdown]
# Loop through all url's and create a dictionary with the information, in order to later convert it to pandas

# %%
list_of_dict = []
j=1
for link in teams_url_list:
    url = link
    response = requests.get(url)
    soup = bs(response.text, 'lxml')
    
    team_info = soup.find('div', class_='pl-3')
    team_name = team_info.h1.text
    team_league = team_info.h2.text
    
    results = soup.find_all('li', class_ = 'list-group-item')
    
    for i in range(len(results)): 
        item = results[i].getText(separator='/')
        descriptor = item[:item.find('/')]
        if descriptor == 'Equipo Rival':
            equipo_rival = item[item.find('/')+1:]
        elif descriptor == 'Ataque':
            ataque = item[item.find('/')+1:]
        elif descriptor == 'Mediocampo':
            mediocampo = item[item.find('/')+1:]
        elif descriptor == 'Defensa':
            defensa = item[item.find('/')+1:]
        else:
            descriptor = item[:item.find('\n')]
            if descriptor == 'Presupuesto De Traspasos':
                presupuesto_de_traspasos_euro = item[item.find('€')+1:item.find('$')-3]
    
    miDict = {'team_name': team_name,
             'team_league': team_league,
             'rival_team': equipo_rival,
             'attack': ataque,
             'midfield': mediocampo,
             'defence': defensa,
             'transfer_budget': presupuesto_de_traspasos_euro,}
    
    list_of_dict.append(miDict)
    print(f"Link {j} completed")
    j = j+ 1
# Out:
# Link 1 completed
# Link 2 completed
# Link 3 completed
# Link 4 completed
# Link 5 completed
# Link 6 completed
# Link 7 completed
# Link 8 completed
# Link 9 completed
# Link 10 completed
# Link 11 completed
# Link 12 completed
# Link 13 completed
# Link 14 completed
# Link 15 completed
# Link 16 completed
# Link 17 completed
# Link 18 completed
# Link 19 completed
# Link 20 completed
# Link 21 completed
# Link 22 completed
# Link 23 completed
# Link 24 completed
# Link 25 completed
# Link 26 completed
# Link 27 completed
# Link 28 completed
# Link 29 completed
# Link 30 completed
# Link 31 completed
# Link 32 completed
# Link 33 completed
# Link 34 completed
# Link 35 completed
# Link 36 completed
# Link 37 completed
# Link 38 completed
# Link 39 completed
# Link 40 completed
# Link 41 completed
# Link 42 completed
# Link 43 completed
# Link 44 completed
# Link 45 completed
# Link 46 completed
# Link 47 completed
# Link 48 completed
# Link 49 completed
# Link 50 completed
# Link 51 completed
# Link 52 completed
# Link 53 completed
# Link 54 completed
# Link 55 completed
# Link 56 completed
# Link 57 completed
# Link 58 completed
# Link 59 completed
# Link 60 completed
# Link 61 completed
# Link 62 completed
# Link 63 completed
# Link 64 completed
# Link 65 completed
# Link 66 completed
# Link 67 completed
# Link 68 completed
# Link 69 completed
# Link 70 completed
# Link 574 completed
# Link 575 completed
# Link 576 completed
# Link 577 completed
# Link 578 completed
# Link 579 completed
# Link 580 completed
# Link 581 completed
# Link 582 completed
# Link 583 completed
# Link 584 completed
# Link 585 completed
# Link 586 completed
# Link 587 completed
# Link 588 completed
# Link 589 completed
# Link 590 completed
# Link 591 completed
# Link 592 completed
# Link 593 completed
# Link 594 completed
# Link 595 completed
# Link 596 completed
# Link 597 completed
# Link 598 completed
# Link 599 completed
# Link 600 completed
# Link 601 completed
# Link 602 completed
# Link 603 completed
# Link 604 completed
# Link 605 completed
# Link 606 completed
# Link 607 completed
# Link 608 completed
# Link 609 completed
# Link 610 completed
# Link 611 completed
# Link 612 completed
# Link 613 completed
# Link 614 completed
# Link 615 completed
# Link 616 completed
# Link 617 completed
# Link 618 completed
# Link 619 completed
# Link 620 completed
# Link 621 completed
# Link 622 completed
# Link 623 completed
# Link 624 completed
# Link 625 completed
# Link 626 completed
# Link 627 completed
# Link 628 completed
# Link 629 completed
# Link 630 completed
# Link 631 completed
# Link 632 completed
# Link 633 completed
# Link 634 completed
# Link 635 completed
# Link 636 completed
# Link 637 completed
# Link 638 completed
# Link 639 completed
# Link 640 completed
# Link 641 completed
# Link 642 completed
# Link 643 completed
# Link 644 completed
# Link 645 completed
# Link 646 completed
# Link 647 completed
# Link 648 completed
# Link 649 completed
# Link 650 completed
# Link 651 completed
# Link 652 completed

# %%
teams = pd.DataFrame(list_of_dict)
teams.head()
# Out:
#   attack defence midfield      rival_team       team_league        team_name  \
# 0     87      85       86     Real Madrid  LaLiga Santander     FC Barcelona
# 1     83      86       88    FC Barcelona  LaLiga Santander      Real Madrid
# 2     89      85       84  Inter de Milán       Serie A TIM         Juventus
# 3     86      83       88  Manchester Utd    Premier League  Manchester City
# 4     85      85       85   Bor. Dortmund        Bundesliga        FC Bayern
#
#   transfer_budget
# 0     188.000.000
# 1     188.500.000
# 2      90.000.000
# 3     170.000.000
# 4     100.000.000

# %% [markdown]
# # Data Transformation
# Transform and normalize scrapped data

# %% [markdown]
# ## FIFA teams data exploration and re-arrangement

# %%
teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 7 columns):
# attack             652 non-null object
# defence            652 non-null object
# midfield           652 non-null object
# rival_team         652 non-null object
# team_league        652 non-null object
# team_name          652 non-null object
# transfer_budget    652 non-null object
# dtypes: object(7)
# memory usage: 35.7+ KB

# %%
print(f"Number of teams: {teams['team_name'].nunique()}")
print(f"Number of leagues: {teams['team_league'].nunique()}")
# Out:
# Number of teams: 651
# Number of leagues: 38

# %% [markdown]
# There seems to be a duplicated team

# %%
teams.loc[teams['team_name'].duplicated(keep=False)]
# Out:
#     attack defence midfield        rival_team       team_league team_name  \
# 106     74      72       75       Guadalajara  LIGA Bancomer MX   América
# 211     71      71       72  Atlético Mineiro    Liga do Brasil   América
#
#     transfer_budget
# 106      25.000.000
# 211         750.000

# %% [markdown]
# There are two teams with the same name, but they are not duplicated

# %%
teams['team_id'] = teams.index+1
teams = teams[['team_id', 'team_name', 'team_league', 'rival_team', 'attack', 'midfield', 'defence', 'transfer_budget']]
teams.head()
# Out:
#    team_id        team_name       team_league      rival_team attack midfield  \
# 0        1     FC Barcelona  LaLiga Santander     Real Madrid     87       86
# 1        2      Real Madrid  LaLiga Santander    FC Barcelona     83       88
# 2        3         Juventus       Serie A TIM  Inter de Milán     89       84
# 3        4  Manchester City    Premier League  Manchester Utd     86       88
# 4        5        FC Bayern        Bundesliga   Bor. Dortmund     85       85
#
#   defence transfer_budget
# 0      85     188.000.000
# 1      86     188.500.000
# 2      85      90.000.000
# 3      83     170.000.000
# 4      85     100.000.000

# %% [markdown]
# Replace the name of the rial team for its team_id

# %%
teams_dict = teams[['team_name','team_id']].set_index('team_name')
teams_dict = teams_dict.to_dict()['team_id']
teams = teams.rename(columns={'rival_team':'rival_team_id'}).replace({'rival_team_id':teams_dict})
teams.head()
# Out:
#    team_id        team_name       team_league  rival_team_id attack midfield  \
# 0        1     FC Barcelona  LaLiga Santander              2     87       86
# 1        2      Real Madrid  LaLiga Santander              1     83       88
# 2        3         Juventus       Serie A TIM             13     89       84
# 3        4  Manchester City    Premier League             12     86       88
# 4        5        FC Bayern        Bundesliga             15     85       85
#
#   defence transfer_budget
# 0      85     188.000.000
# 1      86     188.500.000
# 2      85      90.000.000
# 3      83     170.000.000
# 4      85     100.000.000

# %% [markdown]
# ### Add the country of the team and replace the the team_league by the league_id

# %%
leagues = pd.DataFrame(teams['team_league'].unique())
leagues = leagues.rename(columns={0:'league_name'})
leagues['league_id'] = leagues.index+1
leagues = leagues.set_index('league_name')
leagues_dict = leagues.to_dict()['league_id'] # This dictionary will be later used to change the team_league for the league_id

leagues=leagues.reset_index()

leagues = leagues[['league_id', 'league_name']]
leagues.head()
# Out:
#    league_id        league_name
# 0          1   LaLiga Santander
# 1          2        Serie A TIM
# 2          3     Premier League
# 3          4         Bundesliga
# 4          5  Ligue 1 Conforama

# %%
league_country_dict = {'LaLiga Santander': 'Spain', 'Serie A TIM': 'Italy', 'Premier League': 'England',
                        'Bundesliga': 'Germany', 'Ligue 1 Conforama': 'France', 'Liga NOS': 'Portugal', 
                        'Eredivisie': 'Netherlands', 'Süper Lig': 'Turkey', 'SAF': 'Argentina', 'Resto del mundo': '', 
                        'Bundesliga 2': 'Germany', 'LIGA Bancomer MX': 'Mexico', 'Pro League': 'Belgium', 
                        'Liga do Brasil': 'Brasil', 'Saudi Professional League': 'Saudi Arabia', 'Ö. Bundesliga': 'Austria', 
                        'Scottish Prem': 'Scotland', 'LaLiga 1 I 2 I 3': 'Spain', 'EFL Championship': 'England',
                        'RSL': 'Switzerland', 'MLS': 'United States', 'Liga Dimayor': 'Colombia', 'Camp. Scotiabank': 'Chile', 
                        'CSL': 'China', "Domino's Ligue 2": 'France', 'Calcio B': 'Italy', 'Superliga': 'Denmark', 
                        'Meiji Yasuda J1': 'Japan', 'Allsvenskan': 'Sweden', 'Eliteserien': 'Norway', 'Ekstraklasa': 'Poland',
                        'K-League 1': 'South Korea', 'EFL League One': 'England', 'Hyundai A-League': 'Australia', 
                        '3. Liga': 'Germany', 'EFL League Two': 'England', 'SSE Airtricity Lge': 'Ireland', 'Agentes Libres': ''}

# %%
teams['country'] = teams['team_league']
teams = teams.replace({'country':league_country_dict})


countries = pd.DataFrame(teams['country'].unique()).rename(columns={0:'country_name'})
countries['country_id'] = countries.index+1
countries = countries.set_index('country_name')
countries_dict = countries.to_dict()['country_id']
countries_dict # This dictionary will be used to change the country for the country_id
countries = countries.reset_index()
countries = countries[['country_id', 'country_name']]
countries.head()
# Out:
#    country_id country_name
# 0           1        Spain
# 1           2        Italy
# 2           3      England
# 3           4      Germany
# 4           5       France

# %% [markdown]
# Handle exceptions

# %%
teams.loc[teams['team_name']=='Montreal Impact']=teams.loc[teams['team_name']=='Montreal Impact'].replace({'country':{'United States':'Canada'}})
teams.loc[teams['team_name']=='Toronto FC']=teams.loc[teams['team_name']=='Toronto FC'].replace({'country':{'United States':'Canada'}})
teams.loc[teams['team_name']=='Whitecaps FC']=teams.loc[teams['team_name']=='Whitecaps FC'].replace({'country':{'United States':'Canada'}})
teams.loc[teams['team_name']=='AS Monaco']=teams.loc[teams['team_name']=='AS Monaco'].replace({'country':{'France':'Monaco'}})

# %% [markdown]
# Replace country name and league name by country_id and league_id

# %%
teams = teams.rename(columns={'country':'country_id', 'team_league':'league_id'})\
                    .replace({'country_id':countries_dict, 'league_id':leagues_dict})

# %%
leagues['main_country_id'] = leagues['league_name']
leagues = leagues.replace({'main_country_id':league_country_dict}).replace({'main_country_id':countries_dict})

leagues.head()
# Out:
#    league_id        league_name  main_country_id
# 0          1   LaLiga Santander                1
# 1          2        Serie A TIM                2
# 2          3     Premier League                3
# 3          4         Bundesliga                4
# 4          5  Ligue 1 Conforama                5

# %% [markdown]
# ## Resulting tables

# %%
teams.head()
# Out:
#    team_id        team_name       team_league  rival_team_id attack midfield  \
# 0        1     FC Barcelona  LaLiga Santander              2     87       86
# 1        2      Real Madrid  LaLiga Santander              1     83       88
# 2        3         Juventus       Serie A TIM             13     89       84
# 3        4  Manchester City    Premier League             12     86       88
# 4        5        FC Bayern        Bundesliga             15     85       85
#
#   defence transfer_budget  country
# 0      85     188.000.000    Spain
# 1      86     188.500.000    Spain
# 2      85      90.000.000    Italy
# 3      83     170.000.000  England
# 4      85     100.000.000  Germany

# %%
leagues.head()
# Out:
#    league_id        league_name  main_country_id
# 0          1   LaLiga Santander                1
# 1          2        Serie A TIM                2
# 2          3     Premier League                3
# 3          4         Bundesliga                4
# 4          5  Ligue 1 Conforama                5

# %%
countries.head()
# Out:
#    country_id country_name
# 0           1        Spain
# 1           2        Italy
# 2           3      England
# 3           4      Germany
# 4           5       France

# %%
teams.to_csv("../Resources/teams.csv", index=False, encoding='UTF-8')
leagues.to_csv("../Resources/leagues.csv", index=False, encoding='UTF-8')
countries.to_csv("../Resources/countries.csv", index=False, encoding='UTF-8')
